# %% [markdown]
# <a href="https://colab.research.google.com/github/floyddeadshot/AlgorandCustodialWallet/blob/master/web3Reader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install web3
# Out:
#   File "<ipython-input-11-59c0d117b202>", line 1
#     pip install web3
#               ^
# SyntaxError: invalid syntax

# %%
pip install requests

# %%
import web3

# %%
import requests

# %%
COVALENT_KEY="ckey_efce3d8efb7146168f78d588413"

# %%
def getTransactionHistory(chainId,address):
  url="https://api.covalenthq.com/v1/"+str(chainId)+"/address/"+address+"/transactions_v2/?key="+COVALENT_KEY
  return requests.get(url).text

# %%
address="0x3ebbd27BF7C1108c98554B2adF6f24F7CdF717C9"
id=1287 #1 for ethereum, 1287 for moonbeam
getTransactionHistory(id,address)
# Out:
# '{"data":{"address":"0x3ebbd27bf7c1108c98554b2adf6f24f7cdf717c9","updated_at":"2022-04-20T00:03:37.063387065Z","next_update_at":"2022-04-20T00:08:37.063387355Z","quote_currency":"USD","chain_id":1,"items":[{"block_signed_at":"2022-04-19T09:42:46Z","block_height":14614809,"tx_hash":"0x1350d26fecba166fc13c4570228ac1e4d99cc9493da1a8db4c68d30f2b9f523e","tx_offset":120,"successful":true,"from_address":"0x3ebbd27bf7c1108c98554b2adf6f24f7cdf717c9","from_address_label":null,"to_address":"0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48","to_address_label":"USD Coin (USDC)","value":"0","value_quote":0.0,"gas_offered":99244,"gas_spent":65625,"gas_price":38181201044,"fees_paid":"2505641318512500","gas_quote":7.658079161339288,"gas_quote_rate":3056.3349609375,"log_events":[{"block_signed_at":"2022-04-19T09:42:46Z","block_height":14614809,"tx_offset":120,"log_offset":202,"tx_hash":"0x1350d26fecba166fc13c4570228ac1e4d99cc9493da1a8db4c68d30f2b9f523e","raw_log_topics":["0xddf252ad1be2c89b69c2b068fc378daa9
# ...
